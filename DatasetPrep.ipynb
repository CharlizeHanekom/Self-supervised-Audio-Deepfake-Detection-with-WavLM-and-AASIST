# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

"""
InTheWildPrep.py - Script for preparing the InTheWild audio dataset

This script:
1. Unzips the dataset (if zipped)
2. Generates comprehensive metadata if none exists
3. Processes the metadata CSV file
4. Prepares the dataset for machine learning use
"""

import numpy as np
import pandas as pd
import os
import shutil
import zipfile

def unzip_dataset(zip_path, extract_to):
    """
    Unzips the dataset file if it exists
    
    Parameters:
    - zip_path (str): Path to the zip file
    - extract_to (str): Directory to extract to
    
    Returns:
    - bool: True if unzipped successfully, False otherwise
    """
    try:
        if not os.path.exists(zip_path):
            print(f"Zip file not found at {zip_path}")
            return False
            
        print(f"Unzipping {zip_path} to {extract_to}...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)
        print("Unzip completed successfully!")
        return True
    except Exception as e:
        print(f"Error unzipping file: {e}")
        return False

def move_file_outside_folder(folder_path, file_name, destination_path):
    """Moves a file outside a folder to a specified destination."""
    try:
        source_path = os.path.join(folder_path, file_name)
        destination_path = os.path.join(destination_path, file_name)
        shutil.move(source_path, destination_path)
        return True
    except FileNotFoundError:
        print(f"File not found: {os.path.join(folder_path, file_name)}")
        return False
    
def generate_metadata(dataset_root):
    """
    Generates comprehensive metadata for the dataset with train/val/test splits
    
    Parameters:
    - dataset_root (str): Root directory of the dataset
    
    Returns:
    - str: Path to the generated metadata file
    """
    metadata = []
    
    for split in ["training", "validation", "testing"]:
        for label in ["real", "fake"]:
            folder_path = os.path.join(dataset_root, split, label)
            
            if not os.path.exists(folder_path):
                print(f"Warning: {folder_path} not found. Skipping...")
                continue
            
            for file in os.listdir(folder_path):
                if file.endswith((".wav", ".flac", ".mp3")):
                    metadata.append({
                        "file": file,
                        "path": os.path.join(folder_path, file),
                        "label": label,
                        "split": split.replace("ing", "")  # "training" → "train"
                    })
    
    df = pd.DataFrame(metadata)
    output_csv = os.path.join(dataset_root, "generated_metadata.csv")
    df.to_csv(output_csv, index=False)
    
    print(f"\nMetadata generation complete. Saved to {output_csv}")
    print(f"Total entries: {len(df)}")
    print("\nCounts by split and label:")
    print(df.groupby(["split", "label"]).size())
    
    return output_csv

def process_metadata(csv_path):
    """Processes the metadata CSV file."""
    try:
        df = pd.read_csv(csv_path)

        # Standardize label names if needed
        if 'label' in df.columns:
            df['label'] = df['label'].replace({'spoof': 'fake', 'bona-fide': 'real'})

        # Clean up speaker column if exists
        if 'speaker' in df.columns:
            df.drop(columns=['speaker'], inplace=True)

        # Ensure split column is properly formatted
        if 'split' in df.columns:
            df['split'] = df['split'].str.replace('ing', '')

        output_csv_path = os.path.join(os.path.dirname(csv_path), 'processed_metadata.csv')
        df.to_csv(output_csv_path, index=False)
        return output_csv_path
    except Exception as e:
        print(f"Error processing metadata: {e}")
        return None

def main():
    base_path = "./data/ASVspoofBalanced"
    zip_file_path = os.path.join(base_path, "BalancedASVspoof2021PA.zip")
    dataset_folder = os.path.join(base_path, "BalancedASVspoof2021PA")
    
    print("Starting dataset preparation...")
    
    # Step 0: Unzip dataset if needed
    print("\nStep 0: Checking for zipped dataset...")
    if os.path.exists(zip_file_path):
        unzip_success = unzip_dataset(zip_file_path, base_path)
    else:
        print("No zip file found, assuming dataset is already extracted")
    
    # Step 1: Check for existing metadata or generate new
    print("\nStep 1: Handling metadata...")
    meta_path = os.path.join(base_path, "meta.csv")
    
    if os.path.exists(meta_path):
        print("Found existing metadata file, processing...")
        processed_meta_path = process_metadata(meta_path)
        print(f"Processed metadata saved to: {processed_meta_path}")
    else:
        print("No existing metadata found, generating new metadata...")
        if os.path.exists(dataset_folder):
            generated_meta_path = generate_metadata(dataset_folder)
            print(f"Generated metadata saved to: {generated_meta_path}")
        else:
            print(f"Error: Dataset folder not found at {dataset_folder}")
    
#     # Step 1: Move meta.csv if needed
#     print("\nStep 1: Moving metadata file...")
#     if os.path.exists(os.path.join(dataset_folder, "meta.csv")):
#         move_success = move_file_outside_folder(
#             folder_path=dataset_folder,
#             file_name="meta.csv",
#             destination_path=base_path
#         )
    
#     # Step 2: Process metadata
#     print("\nStep 2: Processing metadata...")
#     meta_path = os.path.join(base_path, "meta.csv")
#     if os.path.exists(meta_path):
#         modified_meta_path = process_metadata(meta_path)
#         print(f"Modified metadata saved to: {modified_meta_path}")
#     else:
#         print(f"Metadata file not found at {meta_path}")
    
    print("\nDataset preparation completed!")

if __name__ == "__main__":
    main()
# Out:
# Starting dataset preparation...
#
# Step 0: Checking for zipped dataset...
# No zip file found, assuming dataset is already extracted
#
# Step 1: Handling metadata...
# No existing metadata found, generating new metadata...
#
# Metadata generation complete. Saved to ./data/ASVspoofBalanced/generated_metadata.csv
# Total entries: 110468
#
# Counts by split and label:
# label
# fake    50000
# real    60468
# dtype: int64
# Generated metadata saved to: ./data/ASVspoofBalanced/generated_metadata.csv
#
# Dataset preparation completed!

# %%
import os
import shutil

def move_all_files_to_parent(folder_path):
    """
    Moves all files from a subfolder into its parent directory.

    Parameters:
    - folder_path (str): The path to the subfolder whose contents should be moved.
    """
    if not os.path.isdir(folder_path):
        print(f"Folder not found: {folder_path}")
        return

    parent_path = os.path.dirname(folder_path)
    moved_files = 0

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        dest_path = os.path.join(parent_path, filename)

        # Only move files (not subdirectories)
        if os.path.isfile(file_path):
            shutil.move(file_path, dest_path)
            moved_files += 1
            print(f"Moved: {filename}")

    print(f"\nTotal files moved: {moved_files} from '{folder_path}' → '{parent_path}'")

subfolder_to_flatten = 'data/FOR/FOR_dataset/validation'
move_all_files_to_parent(subfolder_to_flatten)

subfolder_to_flatten = 'data/FOR/FOR_dataset/testing'
move_all_files_to_parent(subfolder_to_flatten)

subfolder_to_flatten = 'data/FOR/FOR_dataset/training'
move_all_files_to_parent(subfolder_to_flatten)
# Out:
# Moved: recording15419.wav_norm_mono.wav
# Moved: recording16738.wav_norm_mono.wav
# Moved: recording16713.wav_norm_mono.wav
# Moved: recording15331.wav_norm_mono.wav
# Moved: recording15779.wav_norm_mono.wav
# Moved: recording14870.wav_norm_mono.wav
# Moved: recording16695.wav_norm_mono.wav
# Moved: recording15935.wav_norm_mono.wav
# Moved: recording16493.wav_norm_mono.wav
# Moved: recording14250.wav_norm_mono.wav
# Moved: recording16649.wav_norm_mono.wav
# Moved: recording15563.wav_norm_mono.wav
# Moved: recording14149.wav_norm_mono.wav
# Moved: recording16248.wav_norm_mono.wav
# Moved: recording14361.wav_norm_mono.wav
# Moved: recording15031.wav_norm_mono.wav
# Moved: recording15684.wav_norm_mono.wav
# Moved: recording14935.wav_norm_mono.wav
# Moved: recording15959.wav_norm_mono.wav
# Moved: recording14713.wav_norm_mono.wav
# Moved: recording14920.wav_norm_mono.wav
# Moved: recording16544.wav_norm_mono.wav
# Moved: recording15756.wav_norm_mono.wav
# Moved: recording16223.wav_norm_mono.wav
# Moved: recording14247.wav_norm_mono.wav
# Moved: recording14419.wav_norm_mono.wav
# Moved: recording15956.wav_norm_mono.wav
# Moved: recording16638.wav_norm_mono.wav
# Moved: recording14875.wav_norm_mono.wav
# Moved: recording16451.wav_norm_mono.wav
# Moved: recording14892.wav_norm_mono.wav
# Moved: recording16238.wav_norm_mono.wav
# Moved: recording14621.wav_norm_mono.wav
# Moved: recording14244.wav_norm_mono.wav
# Moved: recording14808.wav_norm_mono.wav
# Moved: recording14138.wav_norm_mono.wav
# Moved: recording15715.wav_norm_mono.wav
# Moved: recording16563.wav_norm_mono.wav
# Moved: recording16685.wav_norm_mono.wav
# Moved: recording14480.wav_norm_mono.wav
# Moved: recording16343.wav_norm_mono.wav
# Moved: recording15496.wav_norm_mono.wav
# Moved: recording15358.wav_norm_mono.wav
# Moved: recording14728.wav_norm_mono.wav
# Moved: recording16247.wav_norm_mono.wav
# Moved: recording14219.wav_norm_mono.wav
# Moved: recording15366.wav_norm_mono.wav
# Moved: recording15922.wav_norm_mono.wav
# Moved: recording15918.wav_norm_mono.wav
# Moved: recording14378.wav_norm_mono.wav
# Moved: recording16725.wav_norm_mono.wav
# Moved: recording16389.wav_norm_mono.wav
# Moved: recording14080.wav_norm_mono.wav
# Moved: recording14890.wav_norm_mono.wav
# Moved: recording14829.wav_norm_mono.wav
# Moved: recording14103.wav_norm_mono.wav
# Moved: recording14915.wav_norm_mono.wav
# Moved: recording14166.wav_norm_mono.wav
# Moved: recording14803.wav_norm_mono.wav
# Moved: recording16418.wav_norm_mono.wav
# Moved: recording15414.wav_norm_mono.wav
# Moved: recording14520.wav_norm_mono.wav
# Moved: recording16211.wav_norm_mono.wav
# Moved: recording15599.wav_norm_mono.wav
# Moved: recording14896.wav_norm_mono.wav
# Moved: recording15566.wav_norm_mono.wav
# Moved: recording16114.wav_norm_mono.wav
# Moved: recording16355.wav_norm_mono.wav
# Moved: recording16341.wav_norm_mono.wav
# Moved: recording15719.wav_norm_mono.wav
# Moved: recording14781.wav_norm_mono.wav
# Moved: recording14979.wav_norm_mono.wav
# Moved: recording16629.wav_norm_mono.wav
# Moved: recording14430.wav_norm_mono.wav
# Moved: recording15268.wav_norm_mono.wav
# Moved: recording14661.wav_norm_mono.wav
# Moved: recording15853.wav_norm_mono.wav
# Moved: recording14055.wav_norm_mono.wav
# Moved: recording15640.wav_norm_mono.wav
# Moved: recording14217.wav_norm_mono.wav
# Moved: recording15739.wav_norm_mono.wav
# Moved: recording14266.wav_norm_mono.wav
# Moved: recording16413.wav_norm_mono.wav
# Moved: recording16333.wav_norm_mono.wav
# Moved: recording15400.wav_norm_mono.wav
# Moved: recording15094.wav_norm_mono.wav
# Moved: recording15058.wav_norm_mono.wav
# Moved: recording14637.wav_norm_mono.wav
# Moved: recording16473.wav_norm_mono.wav
# Moved: recording14845.wav_norm_mono.wav
# Moved: recording15217.wav_norm_mono.wav
# Moved: recording14394.wav_norm_mono.wav
# Moved: recording16104.wav_norm_mono.wav
# Moved: recording15149.wav_norm_mono.wav
# Moved: recording14616.wav_norm_mono.wav
# Moved: recording15260.wav_norm_mono.wav
# Moved: recording15635.wav_norm_mono.wav
# Moved: recording15998.wav_norm_mono.wav
# Moved: recording16647.wav_norm_mono.wav
# Moved: recording16132.wav_norm_mono.wav
# Moved: recording14209.wav_norm_mono.wav
# Moved: recording14499.wav_norm_mono.wav
# Moved: recording16009.wav_norm_mono.wav
# Moved: recording16059.wav_norm_mono.wav
# Moved: recording15740.wav_norm_mono.wav
# Moved: recording15749.wav_norm_mono.wav
# Moved: recording16074.wav_norm_mono.wav
# Moved: recording16714.wav_norm_mono.wav
# Moved: recording14854.wav_norm_mono.wav
# Moved: recording16215.wav_norm_mono.wav
# Moved: recording16262.wav_norm_mono.wav
# Moved: recording15555.wav_norm_mono.wav
# Moved: recording14672.wav_norm_mono.wav
# Moved: recording14367.wav_norm_mono.wav
# Moved: recording16684.wav_norm_mono.wav
# Moved: recording14680.wav_norm_mono.wav
# Moved: recording14071.wav_norm_mono.wav
# Moved: recording14657.wav_norm_mono.wav
# Moved: recording15063.wav_norm_mono.wav
# Moved: recording15229.wav_norm_mono.wav
# Moved: recording16419.wav_norm_mono.wav
# Moved: recording16587.wav_norm_mono.wav
# Moved: recording16496.wav_norm_mono.wav
# Moved: recording16547.wav_norm_mono.wav
# Moved: recording16342.wav_norm_mono.wav
# Moved: recording14374.wav_norm_mono.wav
# Moved: recording14157.wav_norm_mono.wav
# Moved: recording14407.wav_norm_mono.wav
# Moved: recording14380.wav_norm_mono.wav
# Moved: recording15117.wav_norm_mono.wav
# Moved: recording14126.wav_norm_mono.wav
# Moved: recording14862.wav_norm_mono.wav
# Moved: recording15627.wav_norm_mono.wav
# Moved: recording16134.wav_norm_mono.wav
# Moved: recording14087.wav_norm_mono.wav
# Moved: recording16047.wav_norm_mono.wav
# Moved: recording16071.wav_norm_mono.wav
# Moved: recording14403.wav_norm_mono.wav
# Moved: recording15132.wav_norm_mono.wav
# Moved: recording15057.wav_norm_mono.wav
# Moved: recording15438.wav_norm_mono.wav
# Moved: recording14091.wav_norm_mono.wav
# Moved: recording15065.wav_norm_mono.wav
# Moved: recording14866.wav_norm_mono.wav
# Moved: recording16287.wav_norm_mono.wav
# Moved: recording14150.wav_norm_mono.wav
# Moved: recording15775.wav_norm_mono.wav
# Moved: recording15505.wav_norm_mono.wav
# Moved: recording14886.wav_norm_mono.wav
# Moved: recording15904.wav_norm_mono.wav
# Moved: recording14887.wav_norm_mono.wav
# Moved: recording14714.wav_norm_mono.wav
# Moved: recording15296.wav_norm_mono.wav
# Moved: recording14827.wav_norm_mono.wav
# Moved: recording15989.wav_norm_mono.wav
# Moved: recording16291.wav_norm_mono.wav
# Moved: recording16102.wav_norm_mono.wav
# Moved: recording15631.wav_norm_mono.wav
# Moved: recording14768.wav_norm_mono.wav
# Moved: recording15404.wav_norm_mono.wav
# Moved: recording15134.wav_norm_mono.wav
# Moved: recording15300.wav_norm_mono.wav
# Moved: recording15238.wav_norm_mono.wav
# Moved: recording14716.wav_norm_mono.wav
# Moved: recording16007.wav_norm_mono.wav
# Moved: recording16439.wav_norm_mono.wav
# Moved: recording15101.wav_norm_mono.wav
# Moved: recording15758.wav_norm_mono.wav
# Moved: recording15811.wav_norm_mono.wav
# Moved: recording14607.wav_norm_mono.wav
# Moved: recording14416.wav_norm_mono.wav
# Moved: recording16294.wav_norm_mono.wav
# Moved: recording16528.wav_norm_mono.wav
# Moved: recording14356.wav_norm_mono.wav
# Moved: recording15520.wav_norm_mono.wav
# Moved: recording16061.wav_norm_mono.wav
# Moved: recording14600.wav_norm_mono.wav
# Moved: recording16363.wav_norm_mono.wav
# Moved: recording14291.wav_norm_mono.wav
# Moved: recording14985.wav_norm_mono.wav
# Moved: recording15084.wav_norm_mono.wav
# Moved: recording16488.wav_norm_mono.wav
# Moved: recording14355.wav_norm_mono.wav
# Moved: recording14725.wav_norm_mono.wav
# Moved: recording14871.wav_norm_mono.wav
# Moved: recording15009.wav_norm_mono.wav
# Moved: recording15201.wav_norm_mono.wav
# Moved: recording14730.wav_norm_mono.wav
# Moved: recording14234.wav_norm_mono.wav
# Moved: recording16270.wav_norm_mono.wav
# Moved: recording16091.wav_norm_mono.wav
# Moved: recording14541.wav_norm_mono.wav
# Moved: recording16329.wav_norm_mono.wav
# Moved: recording16338.wav_norm_mono.wav
# Moved: recording16176.wav_norm_mono.wav
# Moved: recording15592.wav_norm_mono.wav
# Moved: recording14918.wav_norm_mono.wav
# Moved: recording15158.wav_norm_mono.wav
# Moved: recording15913.wav_norm_mono.wav
# Moved: recording14826.wav_norm_mono.wav
# Moved: recording16609.wav_norm_mono.wav
# Moved: recording15140.wav_norm_mono.wav
# Moved: recording14389.wav_norm_mono.wav
# Moved: recording15712.wav_norm_mono.wav
# Moved: recording15752.wav_norm_mono.wav
# Moved: recording16203.wav_norm_mono.wav
# Moved: recording14295.wav_norm_mono.wav
# Moved: recording14184.wav_norm_mono.wav
# Moved: recording14816.wav_norm_mono.wav
# Moved: recording15929.wav_norm_mono.wav
# Moved: recording16096.wav_norm_mono.wav
# Moved: recording16166.wav_norm_mono.wav
# Moved: recording14997.wav_norm_mono.wav
# Moved: recording16056.wav_norm_mono.wav
# Moved: recording15970.wav_norm_mono.wav
# Moved: recording15807.wav_norm_mono.wav
# Moved: recording16465.wav_norm_mono.wav
# Moved: recording15247.wav_norm_mono.wav
# Moved: recording15564.wav_norm_mono.wav
# Moved: recording15568.wav_norm_mono.wav
# Moved: recording14237.wav_norm_mono.wav
# Moved: recording14924.wav_norm_mono.wav
# Moved: recording16375.wav_norm_mono.wav
# Moved: recording16614.wav_norm_mono.wav
# Moved: recording15253.wav_norm_mono.wav
# Moved: recording14811.wav_norm_mono.wav
# Moved: recording15486.wav_norm_mono.wav
# Moved: recording14411.wav_norm_mono.wav
# Moved: recording15963.wav_norm_mono.wav
# Moved: recording16423.wav_norm_mono.wav
# Moved: recording15230.wav_norm_mono.wav
# Moved: recording15926.wav_norm_mono.wav
# Moved: recording16524.wav_norm_mono.wav
# Moved: recording14050.wav_norm_mono.wav
# Moved: recording14554.wav_norm_mono.wav
# Moved: recording15976.wav_norm_mono.wav
# Moved: recording14650.wav_norm_mono.wav
# Moved: recording15620.wav_norm_mono.wav
# Moved: recording16146.wav_norm_mono.wav
# Moved: recording16097.wav_norm_mono.wav
# Moved: recording14564.wav_norm_mono.wav
# Moved: recording15068.wav_norm_mono.wav
# Moved: recording14485.wav_norm_mono.wav
# Moved: recording14046.wav_norm_mono.wav
# Moved: recording14102.wav_norm_mono.wav
# Moved: recording15637.wav_norm_mono.wav
# Moved: recording14521.wav_norm_mono.wav
# Moved: recording14640.wav_norm_mono.wav
# Moved: recording15219.wav_norm_mono.wav
# Moved: recording14873.wav_norm_mono.wav
# Moved: recording14615.wav_norm_mono.wav
# Moved: recording15087.wav_norm_mono.wav
# Moved: recording15242.wav_norm_mono.wav
# Moved: recording14608.wav_norm_mono.wav
# Moved: recording14392.wav_norm_mono.wav
# Moved: recording14724.wav_norm_mono.wav
# Moved: recording16623.wav_norm_mono.wav
# Moved: recording14802.wav_norm_mono.wav
# Moved: recording14442.wav_norm_mono.wav
# Moved: recording14927.wav_norm_mono.wav
# Moved: recording15624.wav_norm_mono.wav
# Moved: recording16565.wav_norm_mono.wav
# Moved: recording15492.wav_norm_mono.wav
# Moved: recording14427.wav_norm_mono.wav
# Moved: recording16686.wav_norm_mono.wav
# Moved: recording15035.wav_norm_mono.wav
# Moved: recording15478.wav_norm_mono.wav
# Moved: recording15228.wav_norm_mono.wav
# Moved: recording15464.wav_norm_mono.wav
# Moved: recording16574.wav_norm_mono.wav
# Moved: recording16605.wav_norm_mono.wav
# Moved: recording15598.wav_norm_mono.wav
# Moved: recording15048.wav_norm_mono.wav
# Moved: recording15025.wav_norm_mono.wav
# Moved: recording15193.wav_norm_mono.wav
# Moved: recording16084.wav_norm_mono.wav
# Moved: recording15619.wav_norm_mono.wav
# Moved: recording15954.wav_norm_mono.wav
# Moved: recording15710.wav_norm_mono.wav
# Moved: recording14316.wav_norm_mono.wav
# Moved: recording15979.wav_norm_mono.wav
# Moved: recording16111.wav_norm_mono.wav
# Moved: recording16709.wav_norm_mono.wav
# Moved: recording16246.wav_norm_mono.wav
# Moved: recording15388.wav_norm_mono.wav
# Moved: recording15808.wav_norm_mono.wav
# Moved: recording16209.wav_norm_mono.wav
# Moved: recording15508.wav_norm_mono.wav
# Moved: recording14265.wav_norm_mono.wav
# Moved: recording14744.wav_norm_mono.wav
# Moved: recording16400.wav_norm_mono.wav
# Moved: recording15216.wav_norm_mono.wav
# Moved: recording16154.wav_norm_mono.wav
# Moved: recording16489.wav_norm_mono.wav
# Moved: recording16120.wav_norm_mono.wav
# Moved: recording14298.wav_norm_mono.wav
# Moved: recording15321.wav_norm_mono.wav
# Moved: recording15292.wav_norm_mono.wav
# Moved: recording14565.wav_norm_mono.wav
# Moved: recording14660.wav_norm_mono.wav
# Moved: recording14573.wav_norm_mono.wav
# Moved: recording16391.wav_norm_mono.wav
# Moved: recording14450.wav_norm_mono.wav
# Moved: recording16157.wav_norm_mono.wav
# Moved: recording14994.wav_norm_mono.wav
# Moved: recording14939.wav_norm_mono.wav
# Moved: recording16381.wav_norm_mono.wav
# Moved: recording16315.wav_norm_mono.wav
# Moved: recording15798.wav_norm_mono.wav
# Moved: recording15638.wav_norm_mono.wav
# Moved: recording16486.wav_norm_mono.wav
# Moved: recording15897.wav_norm_mono.wav
# Moved: recording15850.wav_norm_mono.wav
# Moved: recording14609.wav_norm_mono.wav
# Moved: recording15030.wav_norm_mono.wav
# Moved: recording15024.wav_norm_mono.wav
# Moved: recording16428.wav_norm_mono.wav
# Moved: recording14868.wav_norm_mono.wav
# Moved: recording14704.wav_norm_mono.wav
# Moved: recording16434.wav_norm_mono.wav
# Moved: recording16584.wav_norm_mono.wav
# Moved: recording15265.wav_norm_mono.wav
# Moved: recording16607.wav_norm_mono.wav
# Moved: recording14548.wav_norm_mono.wav
# Moved: recording14782.wav_norm_mono.wav
# Moved: recording16250.wav_norm_mono.wav
# Moved: recording15570.wav_norm_mono.wav
# Moved: recording16334.wav_norm_mono.wav
# Moved: recording16087.wav_norm_mono.wav
# Moved: recording15055.wav_norm_mono.wav
# Moved: recording16577.wav_norm_mono.wav
# Moved: recording16550.wav_norm_mono.wav
# Moved: recording14161.wav_norm_mono.wav
# Moved: recording15650.wav_norm_mono.wav
# Moved: recording14580.wav_norm_mono.wav
# Moved: recording15411.wav_norm_mono.wav
# Moved: recording14644.wav_norm_mono.wav
# Moved: recording15146.wav_norm_mono.wav
# Moved: recording14198.wav_norm_mono.wav
# Moved: recording14561.wav_norm_mono.wav
# Moved: recording16122.wav_norm_mono.wav
# Moved: recording15493.wav_norm_mono.wav
# Moved: recording14507.wav_norm_mono.wav
# Moved: recording14320.wav_norm_mono.wav
# Moved: recording16216.wav_norm_mono.wav
# Moved: recording14954.wav_norm_mono.wav
# Moved: recording15385.wav_norm_mono.wav
# Moved: recording15549.wav_norm_mono.wav
# Moved: recording14818.wav_norm_mono.wav
# Moved: recording14238.wav_norm_mono.wav
# Moved: recording15868.wav_norm_mono.wav
# Moved: recording15688.wav_norm_mono.wav
# Moved: recording16478.wav_norm_mono.wav
# Moved: recording14562.wav_norm_mono.wav
# Moved: recording15095.wav_norm_mono.wav
# Moved: recording16461.wav_norm_mono.wav
# Moved: recording16129.wav_norm_mono.wav
# Moved: recording14585.wav_norm_mono.wav
# Moved: recording14904.wav_norm_mono.wav
# Moved: recording14467.wav_norm_mono.wav
# Moved: recording16435.wav_norm_mono.wav
# Moved: recording15652.wav_norm_mono.wav
# Moved: recording16138.wav_norm_mono.wav
# Moved: recording16290.wav_norm_mono.wav
# Moved: recording15804.wav_norm_mono.wav
# Moved: recording14688.wav_norm_mono.wav
# Moved: recording15317.wav_norm_mono.wav
# Moved: recording14437.wav_norm_mono.wav
# Moved: recording16264.wav_norm_mono.wav
# Moved: recording16242.wav_norm_mono.wav
# Moved: recording16344.wav_norm_mono.wav
# Moved: recording16066.wav_norm_mono.wav
# Moved: recording16050.wav_norm_mono.wav
# Moved: recording15633.wav_norm_mono.wav
# Moved: recording14719.wav_norm_mono.wav
# Moved: recording15254.wav_norm_mono.wav
# Moved: recording14338.wav_norm_mono.wav
# Moved: recording14363.wav_norm_mono.wav
# Moved: recording16263.wav_norm_mono.wav
# Moved: recording14500.wav_norm_mono.wav
# Moved: recording16372.wav_norm_mono.wav
# Moved: recording15067.wav_norm_mono.wav
# Moved: recording16637.wav_norm_mono.wav
# Moved: recording15387.wav_norm_mono.wav
# Moved: recording15162.wav_norm_mono.wav
# Moved: recording15235.wav_norm_mono.wav
# Moved: recording14574.wav_norm_mono.wav
# Moved: recording16534.wav_norm_mono.wav
# Moved: recording14131.wav_norm_mono.wav
# Moved: recording14926.wav_norm_mono.wav
# Moved: recording14271.wav_norm_mono.wav
# Moved: recording14197.wav_norm_mono.wav
# Moved: recording16538.wav_norm_mono.wav
# Moved: recording14193.wav_norm_mono.wav
# Moved: recording14586.wav_norm_mono.wav
# Moved: recording14763.wav_norm_mono.wav
# Moved: recording14605.wav_norm_mono.wav
# Moved: recording14375.wav_norm_mono.wav
# Moved: recording16139.wav_norm_mono.wav
# Moved: recording15039.wav_norm_mono.wav
# Moved: recording14842.wav_norm_mono.wav
# Moved: recording15530.wav_norm_mono.wav
# Moved: recording14060.wav_norm_mono.wav
# Moved: recording14821.wav_norm_mono.wav
# Moved: recording16034.wav_norm_mono.wav
# Moved: recording16003.wav_norm_mono.wav
# Moved: recording14903.wav_norm_mono.wav
# Moved: recording15891.wav_norm_mono.wav
# Moved: recording15075.wav_norm_mono.wav
# Moved: recording15516.wav_norm_mono.wav
# Moved: recording14792.wav_norm_mono.wav
# Moved: recording14832.wav_norm_mono.wav
# Moved: recording15803.wav_norm_mono.wav
# Moved: recording15443.wav_norm_mono.wav
# Moved: recording15082.wav_norm_mono.wav
# Moved: recording16483.wav_norm_mono.wav
# Moved: recording15607.wav_norm_mono.wav
# Moved: recording16698.wav_norm_mono.wav
# Moved: recording14840.wav_norm_mono.wav
# Moved: recording14847.wav_norm_mono.wav
# Moved: recording14329.wav_norm_mono.wav
# Moved: recording15923.wav_norm_mono.wav
# Moved: recording15526.wav_norm_mono.wav
# Moved: recording16357.wav_norm_mono.wav
# Moved: recording15699.wav_norm_mono.wav
# Moved: recording15996.wav_norm_mono.wav
# Moved: recording15969.wav_norm_mono.wav
# Moved: recording15871.wav_norm_mono.wav
# Moved: recording16001.wav_norm_mono.wav
# Moved: recording16353.wav_norm_mono.wav
# Moved: recording15980.wav_norm_mono.wav
# Moved: recording15314.wav_norm_mono.wav
# Moved: recording16604.wav_norm_mono.wav
# Moved: recording14490.wav_norm_mono.wav
# Moved: recording15561.wav_norm_mono.wav
# Moved: recording15985.wav_norm_mono.wav
# Moved: recording14479.wav_norm_mono.wav
# Moved: recording14359.wav_norm_mono.wav
# Moved: recording15912.wav_norm_mono.wav
# Moved: recording16555.wav_norm_mono.wav
# Moved: recording14601.wav_norm_mono.wav
# Moved: recording16567.wav_norm_mono.wav
# Moved: recording15842.wav_norm_mono.wav
# Moved: recording14962.wav_norm_mono.wav
# Moved: recording15718.wav_norm_mono.wav
# Moved: recording14634.wav_norm_mono.wav
# Moved: recording16174.wav_norm_mono.wav
# Moved: recording15179.wav_norm_mono.wav
# Moved: recording14721.wav_norm_mono.wav
# Moved: recording15044.wav_norm_mono.wav
# Moved: recording15697.wav_norm_mono.wav
# Moved: recording15433.wav_norm_mono.wav
# Moved: recording15020.wav_norm_mono.wav
# Moved: recording14474.wav_norm_mono.wav
# Moved: recording14369.wav_norm_mono.wav
# Moved: recording16185.wav_norm_mono.wav
# Moved: recording16150.wav_norm_mono.wav
# Moved: recording14333.wav_norm_mono.wav
# Moved: recording15494.wav_norm_mono.wav
# Moved: recording15617.wav_norm_mono.wav
# Moved: recording16281.wav_norm_mono.wav
# Moved: recording14851.wav_norm_mono.wav
# Moved: recording15792.wav_norm_mono.wav
# Moved: recording14483.wav_norm_mono.wav
# Moved: recording15795.wav_norm_mono.wav
# Moved: recording15380.wav_norm_mono.wav
# Moved: recording15336.wav_norm_mono.wav
# Moved: recording16466.wav_norm_mono.wav
# Moved: recording16588.wav_norm_mono.wav
# Moved: recording14718.wav_norm_mono.wav
# Moved: recording15092.wav_norm_mono.wav
# Moved: recording16158.wav_norm_mono.wav
# Moved: recording14631.wav_norm_mono.wav
# Moved: recording15412.wav_norm_mono.wav
# Moved: recording15648.wav_norm_mono.wav
# Moved: recording14646.wav_norm_mono.wav
# Moved: recording16705.wav_norm_mono.wav
# Moved: recording15000.wav_norm_mono.wav
# Moved: recording15671.wav_norm_mono.wav
# Moved: recording14513.wav_norm_mono.wav
# Moved: recording16152.wav_norm_mono.wav
# Moved: recording14765.wav_norm_mono.wav
# Moved: recording14508.wav_norm_mono.wav
# Moved: recording14111.wav_norm_mono.wav
# Moved: recording15293.wav_norm_mono.wav
# Moved: recording16467.wav_norm_mono.wav
# Moved: recording16068.wav_norm_mono.wav
# Moved: recording14158.wav_norm_mono.wav
# Moved: recording15391.wav_norm_mono.wav
# Moved: recording15284.wav_norm_mono.wav
# Moved: recording15901.wav_norm_mono.wav
# Moved: recording16416.wav_norm_mono.wav
# Moved: recording15383.wav_norm_mono.wav
# Moved: recording15532.wav_norm_mono.wav
# Moved: recording14912.wav_norm_mono.wav
# Moved: recording16179.wav_norm_mono.wav
# Moved: recording15512.wav_norm_mono.wav
# Moved: recording14372.wav_norm_mono.wav
# Moved: recording15041.wav_norm_mono.wav
# Moved: recording14078.wav_norm_mono.wav
# Moved: recording16089.wav_norm_mono.wav
# Moved: recording16573.wav_norm_mono.wav
# Moved: recording14647.wav_norm_mono.wav
# Moved: recording15027.wav_norm_mono.wav
# Moved: recording16278.wav_norm_mono.wav
# Moved: recording14330.wav_norm_mono.wav
# Moved: recording15559.wav_norm_mono.wav
# Moved: recording16293.wav_norm_mono.wav
# Moved: recording14246.wav_norm_mono.wav
# Moved: recording15580.wav_norm_mono.wav
# Moved: recording15742.wav_norm_mono.wav
# Moved: recording14340.wav_norm_mono.wav
# Moved: recording15877.wav_norm_mono.wav
# Moved: recording14323.wav_norm_mono.wav
# Moved: recording14578.wav_norm_mono.wav
# Moved: recording14784.wav_norm_mono.wav
# Moved: recording14869.wav_norm_mono.wav
# Moved: recording16589.wav_norm_mono.wav
# Moved: recording16105.wav_norm_mono.wav
# Moved: recording14465.wav_norm_mono.wav
# Moved: recording16181.wav_norm_mono.wav
# Moved: recording15541.wav_norm_mono.wav
# Moved: recording16556.wav_norm_mono.wav
# Moved: recording14296.wav_norm_mono.wav
# Moved: recording15760.wav_norm_mono.wav
# Moved: recording15218.wav_norm_mono.wav
# Moved: recording16484.wav_norm_mono.wav
# Moved: recording16468.wav_norm_mono.wav
# Moved: recording16156.wav_norm_mono.wav
# Moved: recording15920.wav_norm_mono.wav
# Moved: recording14598.wav_norm_mono.wav
# Moved: recording16080.wav_norm_mono.wav
# Moved: recording16511.wav_norm_mono.wav
# Moved: recording15304.wav_norm_mono.wav
# Moved: recording14410.wav_norm_mono.wav
# Moved: recording15466.wav_norm_mono.wav
# Moved: recording15066.wav_norm_mono.wav
# Moved: recording16058.wav_norm_mono.wav
# Moved: recording16103.wav_norm_mono.wav
# Moved: recording16346.wav_norm_mono.wav
# Moved: recording14070.wav_norm_mono.wav
# Moved: recording16161.wav_norm_mono.wav
# Moved: recording15196.wav_norm_mono.wav
# Moved: recording15083.wav_norm_mono.wav
# Moved: recording15727.wav_norm_mono.wav
# Moved: recording14144.wav_norm_mono.wav
# Moved: recording14278.wav_norm_mono.wav
# Moved: recording15557.wav_norm_mono.wav
# Moved: recording14642.wav_norm_mono.wav
# Moved: recording16172.wav_norm_mono.wav
# Moved: recording14651.wav_norm_mono.wav
# Moved: recording16324.wav_norm_mono.wav
# Moved: recording14222.wav_norm_mono.wav
# Moved: recording16371.wav_norm_mono.wav
# Moved: recording14736.wav_norm_mono.wav
# Moved: recording15168.wav_norm_mono.wav
# Moved: recording16183.wav_norm_mono.wav
# Moved: recording16553.wav_norm_mono.wav
# Moved: recording15768.wav_norm_mono.wav
# Moved: recording14732.wav_norm_mono.wav
# Moved: recording14160.wav_norm_mono.wav
# Moved: recording14472.wav_norm_mono.wav
# Moved: recording16474.wav_norm_mono.wav
# Moved: recording16477.wav_norm_mono.wav
# Moved: recording14908.wav_norm_mono.wav
# Moved: recording15344.wav_norm_mono.wav
# Moved: recording14433.wav_norm_mono.wav
# Moved: recording16036.wav_norm_mono.wav
# Moved: recording14129.wav_norm_mono.wav
# Moved: recording15295.wav_norm_mono.wav
# Moved: recording16652.wav_norm_mono.wav
# Moved: recording15743.wav_norm_mono.wav
# Moved: recording16399.wav_norm_mono.wav
# Moved: recording16165.wav_norm_mono.wav
# Moved: recording16734.wav_norm_mono.wav
# Moved: recording15332.wav_norm_mono.wav
# Moved: recording16280.wav_norm_mono.wav
# Moved: recording16564.wav_norm_mono.wav
# Moved: recording14366.wav_norm_mono.wav
# Moved: recording15962.wav_norm_mono.wav
# Moved: recording16049.wav_norm_mono.wav
# Moved: recording15581.wav_norm_mono.wav
# Moved: recording15014.wav_norm_mono.wav
# Moved: recording16566.wav_norm_mono.wav
# Moved: recording14658.wav_norm_mono.wav
# Moved: recording16356.wav_norm_mono.wav
# Moved: recording15015.wav_norm_mono.wav
# Moved: recording16274.wav_norm_mono.wav
# Moved: recording14456.wav_norm_mono.wav
# Moved: recording16452.wav_norm_mono.wav
# Moved: recording14130.wav_norm_mono.wav
# Moved: recording15655.wav_norm_mono.wav
# Moved: recording16361.wav_norm_mono.wav
# Moved: recording14373.wav_norm_mono.wav
# Moved: recording15052.wav_norm_mono.wav
# Moved: recording14806.wav_norm_mono.wav
# Moved: recording14645.wav_norm_mono.wav
# Moved: recording14307.wav_norm_mono.wav
# Moved: recording15472.wav_norm_mono.wav
# Moved: recording16593.wav_norm_mono.wav
# Moved: recording16531.wav_norm_mono.wav
# Moved: recording15747.wav_norm_mono.wav
# Moved: recording14575.wav_norm_mono.wav
# Moved: recording15666.wav_norm_mono.wav
# Moved: recording15396.wav_norm_mono.wav
# Moved: recording14553.wav_norm_mono.wav
# Moved: recording15174.wav_norm_mono.wav
# Moved: recording14202.wav_norm_mono.wav
# Moved: recording16128.wav_norm_mono.wav
# Moved: recording14207.wav_norm_mono.wav
# Moved: recording16407.wav_norm_mono.wav
# Moved: recording16020.wav_norm_mono.wav
# Moved: recording14341.wav_norm_mono.wav
# Moved: recording14934.wav_norm_mono.wav
# Moved: recording15187.wav_norm_mono.wav
# Moved: recording14793.wav_norm_mono.wav
# Moved: recording14710.wav_norm_mono.wav
# Moved: recording15294.wav_norm_mono.wav
# Moved: recording14946.wav_norm_mono.wav
# Moved: recording14733.wav_norm_mono.wav
# Moved: recording15983.wav_norm_mono.wav
# Moved: recording14379.wav_norm_mono.wav
# Moved: recording16214.wav_norm_mono.wav
# Moved: recording15761.wav_norm_mono.wav
# Moved: recording15436.wav_norm_mono.wav
# Moved: recording16327.wav_norm_mono.wav
# Moved: recording15506.wav_norm_mono.wav
# Moved: recording15465.wav_norm_mono.wav
# Moved: recording16718.wav_norm_mono.wav
# Moved: recording15524.wav_norm_mono.wav
# Moved: recording16448.wav_norm_mono.wav
# Moved: recording14877.wav_norm_mono.wav
# Moved: recording14595.wav_norm_mono.wav
# Moved: recording15159.wav_norm_mono.wav
# Moved: recording15942.wav_norm_mono.wav
# Moved: recording15728.wav_norm_mono.wav
# Moved: recording15973.wav_norm_mono.wav
# Moved: recording15032.wav_norm_mono.wav
# Moved: recording14322.wav_norm_mono.wav
# Moved: recording16655.wav_norm_mono.wav
# Moved: recording16562.wav_norm_mono.wav
# Moved: recording15993.wav_norm_mono.wav
# Moved: recording14998.wav_norm_mono.wav
# Moved: recording16070.wav_norm_mono.wav
# Moved: recording15211.wav_norm_mono.wav
# Moved: recording14245.wav_norm_mono.wav
# Moved: recording14771.wav_norm_mono.wav
# Moved: recording15399.wav_norm_mono.wav
# Moved: recording14218.wav_norm_mono.wav
# Moved: recording15350.wav_norm_mono.wav
# Moved: recording14104.wav_norm_mono.wav
# Moved: recording16700.wav_norm_mono.wav
# Moved: recording16424.wav_norm_mono.wav
# Moved: recording15571.wav_norm_mono.wav
# Moved: recording14225.wav_norm_mono.wav
# Moved: recording14778.wav_norm_mono.wav
# Moved: recording14673.wav_norm_mono.wav
# Moved: recording14302.wav_norm_mono.wav
# Moved: recording15773.wav_norm_mono.wav
# Moved: recording14331.wav_norm_mono.wav
# Moved: recording14740.wav_norm_mono.wav
# Moved: recording16224.wav_norm_mono.wav
# Moved: recording15147.wav_norm_mono.wav
# Moved: recording16736.wav_norm_mono.wav
# Moved: recording15865.wav_norm_mono.wav
# Moved: recording14518.wav_norm_mono.wav
# Moved: recording16409.wav_norm_mono.wav
# Moved: recording16510.wav_norm_mono.wav
# Moved: recording15696.wav_norm_mono.wav
# Moved: recording14110.wav_norm_mono.wav
# Moved: recording15709.wav_norm_mono.wav
# Moved: recording15704.wav_norm_mono.wav
# Moved: recording14987.wav_norm_mono.wav
# Moved: recording16145.wav_norm_mono.wav
# Moved: recording14897.wav_norm_mono.wav
# Moved: recording16630.wav_norm_mono.wav
# Moved: recording14863.wav_norm_mono.wav
# Moved: recording16253.wav_norm_mono.wav
# Moved: recording14153.wav_norm_mono.wav
# Moved: recording16063.wav_norm_mono.wav
# Moved: recording14299.wav_norm_mono.wav
# Moved: recording16194.wav_norm_mono.wav
# Moved: recording14674.wav_norm_mono.wav
# Moved: recording15011.wav_norm_mono.wav
# Moved: recording15606.wav_norm_mono.wav
# Moved: recording15789.wav_norm_mono.wav
# Moved: recording14804.wav_norm_mono.wav
# Moved: recording14328.wav_norm_mono.wav
# Moved: recording14844.wav_norm_mono.wav
# Moved: recording16708.wav_norm_mono.wav
# Moved: recording14445.wav_norm_mono.wav
# Moved: recording15118.wav_norm_mono.wav
# Moved: recording15286.wav_norm_mono.wav
# Moved: recording15269.wav_norm_mono.wav
# Moved: recording15204.wav_norm_mono.wav
# Moved: recording16410.wav_norm_mono.wav
# Moved: recording14654.wav_norm_mono.wav
# Moved: recording16396.wav_norm_mono.wav
# Moved: recording14170.wav_norm_mono.wav
# Moved: recording15004.wav_norm_mono.wav
# Moved: recording14944.wav_norm_mono.wav
# Moved: recording14812.wav_norm_mono.wav
# Moved: recording14085.wav_norm_mono.wav
# Moved: recording15195.wav_norm_mono.wav
# Moved: recording15210.wav_norm_mono.wav
# Moved: recording15887.wav_norm_mono.wav
# Moved: recording15802.wav_norm_mono.wav
# Moved: recording15531.wav_norm_mono.wav
# Moved: recording14558.wav_norm_mono.wav
# Moved: recording15013.wav_norm_mono.wav
# Moved: recording14881.wav_norm_mono.wav
# Moved: recording15965.wav_norm_mono.wav
# Moved: recording15124.wav_norm_mono.wav
# Moved: recording14635.wav_norm_mono.wav
# Moved: recording15780.wav_norm_mono.wav
# Moved: recording14081.wav_norm_mono.wav
# Moved: recording15706.wav_norm_mono.wav
# Moved: recording14694.wav_norm_mono.wav
# Moved: recording14817.wav_norm_mono.wav
# Moved: recording15401.wav_norm_mono.wav
# Moved: recording16737.wav_norm_mono.wav
# Moved: recording14961.wav_norm_mono.wav
# Moved: recording14550.wav_norm_mono.wav
# Moved: recording16213.wav_norm_mono.wav
# Moved: recording15554.wav_norm_mono.wav
# Moved: recording15064.wav_norm_mono.wav
# Moved: recording14493.wav_norm_mono.wav
# Moved: recording16386.wav_norm_mono.wav
# Moved: recording16535.wav_norm_mono.wav
# Moved: recording15679.wav_norm_mono.wav
# Moved: recording15824.wav_norm_mono.wav
# Moved: recording14451.wav_norm_mono.wav
# Moved: recording14746.wav_norm_mono.wav
# Moved: recording14252.wav_norm_mono.wav
# Moved: recording14750.wav_norm_mono.wav
# Moved: recording15034.wav_norm_mono.wav
# Moved: recording16048.wav_norm_mono.wav
# Moved: recording14443.wav_norm_mono.wav
# Moved: recording16282.wav_norm_mono.wav
# Moved: recording14353.wav_norm_mono.wav
# Moved: recording16459.wav_norm_mono.wav
# Moved: recording14439.wav_norm_mono.wav
# Moved: recording15408.wav_norm_mono.wav
# Moved: recording15732.wav_norm_mono.wav
# Moved: recording14159.wav_norm_mono.wav
# Moved: recording14639.wav_norm_mono.wav
# Moved: recording16279.wav_norm_mono.wav
# Moved: recording15774.wav_norm_mono.wav
# Moved: recording15866.wav_norm_mono.wav
# Moved: recording15301.wav_norm_mono.wav
# Moved: recording14555.wav_norm_mono.wav
# Moved: recording16420.wav_norm_mono.wav
# Moved: recording14441.wav_norm_mono.wav
# Moved: recording15952.wav_norm_mono.wav
# Moved: recording14139.wav_norm_mono.wav
# Moved: recording14512.wav_norm_mono.wav
# Moved: recording15656.wav_norm_mono.wav
# Moved: recording14134.wav_norm_mono.wav
# Moved: recording14242.wav_norm_mono.wav
# Moved: recording15028.wav_norm_mono.wav
# Moved: recording14216.wav_norm_mono.wav
# Moved: recording15572.wav_norm_mono.wav
# Moved: recording14282.wav_norm_mono.wav
# Moved: recording15446.wav_norm_mono.wav
# Moved: recording15649.wav_norm_mono.wav
# Moved: recording14090.wav_norm_mono.wav
# Moved: recording14731.wav_norm_mono.wav
# Moved: recording14857.wav_norm_mono.wav
# Moved: recording14988.wav_norm_mono.wav
# Moved: recording15342.wav_norm_mono.wav
# Moved: recording15778.wav_norm_mono.wav
# Moved: recording14956.wav_norm_mono.wav
# Moved: recording14154.wav_norm_mono.wav
# Moved: recording16640.wav_norm_mono.wav
# Moved: recording14049.wav_norm_mono.wav
# Moved: recording14165.wav_norm_mono.wav
# Moved: recording16311.wav_norm_mono.wav
# Moved: recording15103.wav_norm_mono.wav
# Moved: recording14057.wav_norm_mono.wav
# Moved: recording14173.wav_norm_mono.wav
# Moved: recording16021.wav_norm_mono.wav
# Moved: recording16602.wav_norm_mono.wav
# Moved: recording14112.wav_norm_mono.wav
# Moved: recording16491.wav_norm_mono.wav
# Moved: recording14720.wav_norm_mono.wav
# Moved: recording15651.wav_norm_mono.wav
# Moved: recording15215.wav_norm_mono.wav
# Moved: recording15273.wav_norm_mono.wav
# Moved: recording15634.wav_norm_mono.wav
# Moved: recording14617.wav_norm_mono.wav
# Moved: recording14785.wav_norm_mono.wav
# Moved: recording16259.wav_norm_mono.wav
# Moved: recording15306.wav_norm_mono.wav
# Moved: recording15259.wav_norm_mono.wav
# Moved: recording15379.wav_norm_mono.wav
# Moved: recording16125.wav_norm_mono.wav
# Moved: recording15137.wav_norm_mono.wav
# Moved: recording14240.wav_norm_mono.wav
# Moved: recording15721.wav_norm_mono.wav
# Moved: recording14879.wav_norm_mono.wav
# Moved: recording16603.wav_norm_mono.wav
# Moved: recording16306.wav_norm_mono.wav
# Moved: recording14693.wav_norm_mono.wav
# Moved: recording14311.wav_norm_mono.wav
# Moved: recording14509.wav_norm_mono.wav
# Moved: recording14168.wav_norm_mono.wav
# Moved: recording14186.wav_norm_mono.wav
# Moved: recording14477.wav_norm_mono.wav
# Moved: recording16433.wav_norm_mono.wav
# Moved: recording14428.wav_norm_mono.wav
# Moved: recording14552.wav_norm_mono.wav
# Moved: recording15890.wav_norm_mono.wav
# Moved: recording15583.wav_norm_mono.wav
# Moved: recording14526.wav_norm_mono.wav
# Moved: recording14417.wav_norm_mono.wav
# Moved: recording15171.wav_norm_mono.wav
# Moved: recording14519.wav_norm_mono.wav
# Moved: recording14251.wav_norm_mono.wav
# Moved: recording15895.wav_norm_mono.wav
# Moved: recording15663.wav_norm_mono.wav
# Moved: recording14858.wav_norm_mono.wav
# Moved: recording14828.wav_norm_mono.wav
# Moved: recording14933.wav_norm_mono.wav
# Moved: recording16062.wav_norm_mono.wav
# Moved: recording16075.wav_norm_mono.wav
# Moved: recording15847.wav_norm_mono.wav
# Moved: recording14707.wav_norm_mono.wav
# Moved: recording16476.wav_norm_mono.wav
# Moved: recording15755.wav_norm_mono.wav
# Moved: recording16322.wav_norm_mono.wav
# Moved: recording15311.wav_norm_mono.wav
# Moved: recording16628.wav_norm_mono.wav
# Moved: recording15536.wav_norm_mono.wav
# Moved: recording14973.wav_norm_mono.wav
# Moved: recording14885.wav_norm_mono.wav
# Moved: recording15670.wav_norm_mono.wav
# Moved: recording14741.wav_norm_mono.wav
# Moved: recording14717.wav_norm_mono.wav
# Moved: recording15855.wav_norm_mono.wav
# Moved: recording15659.wav_norm_mono.wav
# Moved: recording14226.wav_norm_mono.wav
# Moved: recording14435.wav_norm_mono.wav
# Moved: recording14801.wav_norm_mono.wav
# Moved: recording14776.wav_norm_mono.wav
# Moved: recording15475.wav_norm_mono.wav
# Moved: recording15919.wav_norm_mono.wav
# Moved: recording14534.wav_norm_mono.wav
# Moved: recording15042.wav_norm_mono.wav
# Moved: recording14797.wav_norm_mono.wav
# Moved: recording14326.wav_norm_mono.wav
# Moved: recording14938.wav_norm_mono.wav
# Moved: recording15841.wav_norm_mono.wav
# Moved: recording14538.wav_norm_mono.wav
# Moved: recording14692.wav_norm_mono.wav
# Moved: recording16512.wav_norm_mono.wav
# Moved: recording14495.wav_norm_mono.wav
# Moved: recording16723.wav_norm_mono.wav
# Moved: recording15127.wav_norm_mono.wav
# Moved: recording14865.wav_norm_mono.wav
# Moved: recording15090.wav_norm_mono.wav
# Moved: recording14405.wav_norm_mono.wav
# Moved: recording15931.wav_norm_mono.wav
# Moved: recording15854.wav_norm_mono.wav
# Moved: recording15515.wav_norm_mono.wav
# Moved: recording15882.wav_norm_mono.wav
# Moved: recording16041.wav_norm_mono.wav
# Moved: recording16454.wav_norm_mono.wav
# Moved: recording14470.wav_norm_mono.wav
# Moved: recording14260.wav_norm_mono.wav
# Moved: recording14401.wav_norm_mono.wav
# Moved: recording14344.wav_norm_mono.wav
# Moved: recording14970.wav_norm_mono.wav
# Moved: recording14262.wav_norm_mono.wav
# Moved: recording14155.wav_norm_mono.wav
# Moved: recording14841.wav_norm_mono.wav
# Moved: recording15322.wav_norm_mono.wav
# Moved: recording14364.wav_norm_mono.wav
# Moved: recording16505.wav_norm_mono.wav
# Moved: recording14922.wav_norm_mono.wav
# Moved: recording14913.wav_norm_mono.wav
# Moved: recording15266.wav_norm_mono.wav
# Moved: recording14766.wav_norm_mono.wav
# Moved: recording16245.wav_norm_mono.wav
# Moved: recording16012.wav_norm_mono.wav
# Moved: recording14547.wav_norm_mono.wav
# Moved: recording16497.wav_norm_mono.wav
# Moved: recording14146.wav_norm_mono.wav
# Moved: recording15672.wav_norm_mono.wav
# Moved: recording15341.wav_norm_mono.wav
# Moved: recording15074.wav_norm_mono.wav
# Moved: recording16666.wav_norm_mono.wav
# Moved: recording14898.wav_norm_mono.wav
# Moved: recording16460.wav_norm_mono.wav
# Moved: recording16403.wav_norm_mono.wav
# Moved: recording16257.wav_norm_mono.wav
# Moved: recording14996.wav_norm_mono.wav
# Moved: recording14107.wav_norm_mono.wav
# Moved: recording15809.wav_norm_mono.wav
# Moved: recording14334.wav_norm_mono.wav
# Moved: recording15180.wav_norm_mono.wav
# Moved: recording15176.wav_norm_mono.wav
# Moved: recording14206.wav_norm_mono.wav
# Moved: recording14591.wav_norm_mono.wav
# Moved: recording15621.wav_norm_mono.wav
# Moved: recording14899.wav_norm_mono.wav
# Moved: recording14227.wav_norm_mono.wav
# Moved: recording14127.wav_norm_mono.wav
# Moved: recording14293.wav_norm_mono.wav
# Moved: recording16244.wav_norm_mono.wav
# Moved: recording16537.wav_norm_mono.wav
# Moved: recording14414.wav_norm_mono.wav
# Moved: recording16722.wav_norm_mono.wav
# Moved: recording16726.wav_norm_mono.wav
# Moved: recording14529.wav_norm_mono.wav
# Moved: recording14086.wav_norm_mono.wav
# Moved: recording15484.wav_norm_mono.wav
# Moved: recording16226.wav_norm_mono.wav
# Moved: recording16065.wav_norm_mono.wav
# Moved: recording14264.wav_norm_mono.wav
# Moved: recording16332.wav_norm_mono.wav
# Moved: recording16208.wav_norm_mono.wav
# Moved: recording14457.wav_norm_mono.wav
# Moved: recording15735.wav_norm_mono.wav
# Moved: recording16626.wav_norm_mono.wav
# Moved: recording14940.wav_norm_mono.wav
# Moved: recording14067.wav_norm_mono.wav
# Moved: recording16295.wav_norm_mono.wav
# Moved: recording15111.wav_norm_mono.wav
# Moved: recording16503.wav_norm_mono.wav
# Moved: recording14902.wav_norm_mono.wav
# Moved: recording14769.wav_norm_mono.wav
# Moved: recording14099.wav_norm_mono.wav
# Moved: recording15944.wav_norm_mono.wav
# Moved: recording14287.wav_norm_mono.wav
# Moved: recording16430.wav_norm_mono.wav
# Moved: recording14761.wav_norm_mono.wav
# Moved: recording14065.wav_norm_mono.wav
# Moved: recording14292.wav_norm_mono.wav
# Moved: recording16426.wav_norm_mono.wav
# Moved: recording16680.wav_norm_mono.wav
# Moved: recording15426.wav_norm_mono.wav
# Moved: recording16004.wav_norm_mono.wav
# Moved: recording14093.wav_norm_mono.wav
# Moved: recording15297.wav_norm_mono.wav
# Moved: recording14611.wav_norm_mono.wav
# Moved: recording16432.wav_norm_mono.wav
# Moved: recording15345.wav_norm_mono.wav
# Moved: recording14504.wav_norm_mono.wav
# Moved: recording15843.wav_norm_mono.wav
# Moved: recording15393.wav_norm_mono.wav
# Moved: recording16308.wav_norm_mono.wav
# Moved: recording14592.wav_norm_mono.wav
# Moved: recording15328.wav_norm_mono.wav
# Moved: recording16596.wav_norm_mono.wav
# Moved: recording15885.wav_norm_mono.wav
# Moved: recording16033.wav_norm_mono.wav
# Moved: recording15519.wav_norm_mono.wav
# Moved: recording14047.wav_norm_mono.wav
# Moved: recording14048.wav_norm_mono.wav
# Moved: recording15654.wav_norm_mono.wav
# Moved: recording14968.wav_norm_mono.wav
# Moved: recording16579.wav_norm_mono.wav
# Moved: recording15744.wav_norm_mono.wav
# Moved: recording15521.wav_norm_mono.wav
# Moved: recording16187.wav_norm_mono.wav
# Moved: recording16106.wav_norm_mono.wav
# Moved: recording15793.wav_norm_mono.wav
# Moved: recording14689.wav_norm_mono.wav
# Moved: recording16648.wav_norm_mono.wav
# Moved: recording16304.wav_norm_mono.wav
# Moved: recording15862.wav_norm_mono.wav
# Moved: recording15612.wav_norm_mono.wav
# Moved: recording16370.wav_norm_mono.wav
# Moved: recording15050.wav_norm_mono.wav
# Moved: recording16380.wav_norm_mono.wav
# Moved: recording14824.wav_norm_mono.wav
# Moved: recording15535.wav_norm_mono.wav
# Moved: recording16613.wav_norm_mono.wav
# Moved: recording15165.wav_norm_mono.wav
# Moved: recording14556.wav_norm_mono.wav
# Moved: recording15356.wav_norm_mono.wav
# Moved: recording15148.wav_norm_mono.wav
# Moved: recording16568.wav_norm_mono.wav
# Moved: recording14092.wav_norm_mono.wav
# Moved: recording14515.wav_norm_mono.wav
# Moved: recording14823.wav_norm_mono.wav
# Moved: recording15335.wav_norm_mono.wav
# Moved: recording15622.wav_norm_mono.wav
# Moved: recording14294.wav_norm_mono.wav
# Moved: recording15319.wav_norm_mono.wav
# Moved: recording15948.wav_norm_mono.wav
# Moved: recording15327.wav_norm_mono.wav
# Moved: recording16124.wav_norm_mono.wav
# Moved: recording16081.wav_norm_mono.wav
# Moved: recording14297.wav_norm_mono.wav
# Moved: recording15276.wav_norm_mono.wav
# Moved: recording15386.wav_norm_mono.wav
# Moved: recording15188.wav_norm_mono.wav
# Moved: recording15716.wav_norm_mono.wav
# Moved: recording14066.wav_norm_mono.wav
# Moved: recording14203.wav_norm_mono.wav
# Moved: recording14652.wav_norm_mono.wav
# Moved: recording16693.wav_norm_mono.wav
# Moved: recording14612.wav_norm_mono.wav
# Moved: recording15362.wav_norm_mono.wav
# Moved: recording14188.wav_norm_mono.wav
# Moved: recording16509.wav_norm_mono.wav
# Moved: recording14396.wav_norm_mono.wav
# Moved: recording15937.wav_norm_mono.wav
# Moved: recording15409.wav_norm_mono.wav
# Moved: recording16337.wav_norm_mono.wav
# Moved: recording15033.wav_norm_mono.wav
# Moved: recording16653.wav_norm_mono.wav
# Moved: recording14737.wav_norm_mono.wav
# Moved: recording15987.wav_norm_mono.wav
# Moved: recording16671.wav_norm_mono.wav
# Moved: recording15799.wav_norm_mono.wav
# Moved: recording15846.wav_norm_mono.wav
# Moved: recording14936.wav_norm_mono.wav
# Moved: recording15991.wav_norm_mono.wav
# Moved: recording14179.wav_norm_mono.wav
# Moved: recording14729.wav_norm_mono.wav
# Moved: recording16159.wav_norm_mono.wav
# Moved: recording14682.wav_norm_mono.wav
# Moved: recording14505.wav_norm_mono.wav
# Moved: recording16663.wav_norm_mono.wav
# Moved: recording15685.wav_norm_mono.wav
# Moved: recording15995.wav_norm_mono.wav
# Moved: recording15968.wav_norm_mono.wav
# Moved: recording15239.wav_norm_mono.wav
# Moved: recording15741.wav_norm_mono.wav
# Moved: recording14974.wav_norm_mono.wav
# Moved: recording14056.wav_norm_mono.wav
# Moved: recording14397.wav_norm_mono.wav
# Moved: recording14620.wav_norm_mono.wav
# Moved: recording14232.wav_norm_mono.wav
# Moved: recording15726.wav_norm_mono.wav
# Moved: recording14952.wav_norm_mono.wav
# Moved: recording14653.wav_norm_mono.wav
# Moved: recording15556.wav_norm_mono.wav
# Moved: recording14546.wav_norm_mono.wav
# Moved: recording14342.wav_norm_mono.wav
# Moved: recording15990.wav_norm_mono.wav
# Moved: recording16429.wav_norm_mono.wav
# Moved: recording15613.wav_norm_mono.wav
# Moved: recording16635.wav_norm_mono.wav
# Moved: recording16707.wav_norm_mono.wav
# Moved: recording16191.wav_norm_mono.wav
# Moved: recording16195.wav_norm_mono.wav
# Moved: recording15307.wav_norm_mono.wav
# Moved: recording15308.wav_norm_mono.wav
# Moved: recording15056.wav_norm_mono.wav
# Moved: recording15590.wav_norm_mono.wav
# Moved: recording16699.wav_norm_mono.wav
# Moved: recording16717.wav_norm_mono.wav
# Moved: recording14425.wav_norm_mono.wav
# Moved: recording15116.wav_norm_mono.wav
# Moved: recording14901.wav_norm_mono.wav
# Moved: recording16552.wav_norm_mono.wav
# Moved: recording16406.wav_norm_mono.wav
# Moved: recording16660.wav_norm_mono.wav
# Moved: recording16019.wav_norm_mono.wav
# Moved: recording16525.wav_norm_mono.wav
# Moved: recording15582.wav_norm_mono.wav
# Moved: recording14254.wav_norm_mono.wav
# Moved: recording15928.wav_norm_mono.wav
# Moved: recording15686.wav_norm_mono.wav
# Moved: recording14327.wav_norm_mono.wav
# Moved: recording16661.wav_norm_mono.wav
# Moved: recording16358.wav_norm_mono.wav
# Moved: recording16485.wav_norm_mono.wav
# Moved: recording15192.wav_norm_mono.wav
# Moved: recording15932.wav_norm_mono.wav
# Moved: recording14460.wav_norm_mono.wav
# Moved: recording14743.wav_norm_mono.wav
# Moved: recording15232.wav_norm_mono.wav
# Moved: recording14835.wav_norm_mono.wav
# Moved: recording15097.wav_norm_mono.wav
# Moved: recording14969.wav_norm_mono.wav
# Moved: recording15772.wav_norm_mono.wav
# Moved: recording15949.wav_norm_mono.wav
# Moved: recording14277.wav_norm_mono.wav
# Moved: recording14133.wav_norm_mono.wav
# Moved: recording14444.wav_norm_mono.wav
# Moved: recording14735.wav_norm_mono.wav
# Moved: recording16732.wav_norm_mono.wav
# Moved: recording15576.wav_norm_mono.wav
# Moved: recording15263.wav_norm_mono.wav
# Moved: recording16394.wav_norm_mono.wav
# Moved: recording14907.wav_norm_mono.wav
# Moved: recording16090.wav_norm_mono.wav
# Moved: recording14423.wav_norm_mono.wav
# Moved: recording14942.wav_norm_mono.wav
# Moved: recording14140.wav_norm_mono.wav
# Moved: recording15552.wav_norm_mono.wav
# Moved: recording14463.wav_norm_mono.wav
# Moved: recording16398.wav_norm_mono.wav
# Moved: recording14317.wav_norm_mono.wav
# Moved: recording15681.wav_norm_mono.wav
# Moved: recording14643.wav_norm_mono.wav
# Moved: recording14498.wav_norm_mono.wav
# Moved: recording16310.wav_norm_mono.wav
# Moved: recording14434.wav_norm_mono.wav
# Moved: recording15906.wav_norm_mono.wav
# Moved: recording14703.wav_norm_mono.wav
# Moved: recording14864.wav_norm_mono.wav
# Moved: recording14084.wav_norm_mono.wav
# Moved: recording14594.wav_norm_mono.wav
# Moved: recording14406.wav_norm_mono.wav
# Moved: recording14462.wav_norm_mono.wav
# Moved: recording14630.wav_norm_mono.wav
# Moved: recording14982.wav_norm_mono.wav
# Moved: recording14116.wav_norm_mono.wav
# Moved: recording14468.wav_norm_mono.wav
# Moved: recording16265.wav_norm_mono.wav
# Moved: recording16392.wav_norm_mono.wav
# Moved: recording15736.wav_norm_mono.wav
# Moved: recording15305.wav_norm_mono.wav
# Moved: recording15762.wav_norm_mono.wav
# Moved: recording16449.wav_norm_mono.wav
# Moved: recording14588.wav_norm_mono.wav
# Moved: recording14303.wav_norm_mono.wav
# Moved: recording14567.wav_norm_mono.wav
# Moved: recording15470.wav_norm_mono.wav
# Moved: recording16082.wav_norm_mono.wav
# Moved: recording14256.wav_norm_mono.wav
# Moved: recording14059.wav_norm_mono.wav
# Moved: recording16586.wav_norm_mono.wav
# Moved: recording16404.wav_norm_mono.wav
# Moved: recording16642.wav_norm_mono.wav
# Moved: recording14426.wav_norm_mono.wav
# Moved: recording14779.wav_norm_mono.wav
# Moved: recording16688.wav_norm_mono.wav
# Moved: recording16229.wav_norm_mono.wav
# Moved: recording16387.wav_norm_mono.wav
# Moved: recording15794.wav_norm_mono.wav
# Moved: recording14980.wav_norm_mono.wav
# Moved: recording14874.wav_norm_mono.wav
# Moved: recording15714.wav_norm_mono.wav
# Moved: recording15378.wav_norm_mono.wav
# Moved: recording14301.wav_norm_mono.wav
# Moved: recording16659.wav_norm_mono.wav
# Moved: recording15182.wav_norm_mono.wav
# Moved: recording14665.wav_norm_mono.wav
# Moved: recording15128.wav_norm_mono.wav
# Moved: recording14181.wav_norm_mono.wav
# Moved: recording16395.wav_norm_mono.wav
# Moved: recording14108.wav_norm_mono.wav
# Moved: recording16598.wav_norm_mono.wav
# Moved: recording15614.wav_norm_mono.wav
# Moved: recording14045.wav_norm_mono.wav
# Moved: recording15255.wav_norm_mono.wav
# Moved: recording16373.wav_norm_mono.wav
# Moved: recording14577.wav_norm_mono.wav
# Moved: recording16323.wav_norm_mono.wav
# Moved: recording15172.wav_norm_mono.wav
# Moved: recording15777.wav_norm_mono.wav
# Moved: recording15469.wav_norm_mono.wav
# Moved: recording14072.wav_norm_mono.wav
# Moved: recording15170.wav_norm_mono.wav
# Moved: recording14967.wav_norm_mono.wav
# Moved: recording16450.wav_norm_mono.wav
# Moved: recording15415.wav_norm_mono.wav
# Moved: recording15984.wav_norm_mono.wav
# Moved: recording14511.wav_norm_mono.wav
# Moved: recording14943.wav_norm_mono.wav
# Moved: recording14272.wav_norm_mono.wav
# Moved: recording16347.wav_norm_mono.wav
# Moved: recording15277.wav_norm_mono.wav
# Moved: recording14305.wav_norm_mono.wav
# Moved: recording14376.wav_norm_mono.wav
# Moved: recording15086.wav_norm_mono.wav
# Moved: recording16710.wav_norm_mono.wav
# Moved: recording15972.wav_norm_mono.wav
# Moved: recording16608.wav_norm_mono.wav
# Moved: recording15833.wav_norm_mono.wav
# Moved: recording15144.wav_norm_mono.wav
# Moved: recording15330.wav_norm_mono.wav
# Moved: recording16369.wav_norm_mono.wav
# Moved: recording15766.wav_norm_mono.wav
# Moved: recording14955.wav_norm_mono.wav
# Moved: recording15910.wav_norm_mono.wav
# Moved: recording16498.wav_norm_mono.wav
# Moved: recording15533.wav_norm_mono.wav
# Moved: recording15646.wav_norm_mono.wav
# Moved: recording16205.wav_norm_mono.wav
# Moved: recording15560.wav_norm_mono.wav
# Moved: recording15480.wav_norm_mono.wav
# Moved: recording16241.wav_norm_mono.wav
# Moved: recording16585.wav_norm_mono.wav
# Moved: recording16227.wav_norm_mono.wav
# Moved: recording15212.wav_norm_mono.wav
# Moved: recording15037.wav_norm_mono.wav
# Moved: recording14787.wav_norm_mono.wav
# Moved: recording14815.wav_norm_mono.wav
# Moved: recording15298.wav_norm_mono.wav
# Moved: recording16437.wav_norm_mono.wav
# Moved: recording16668.wav_norm_mono.wav
# Moved: recording15085.wav_norm_mono.wav
# Moved: recording14712.wav_norm_mono.wav
# ...
# Moved: recording5920.wav_norm_mono.wav
# Moved: recording11442.wav_norm_mono.wav
# Moved: recording1811.wav_norm_mono.wav
# Moved: recording2761.wav_norm_mono.wav
# Moved: recording4353.wav_norm_mono.wav
# Moved: recording4057.wav_norm_mono.wav
# Moved: recording7793.wav_norm_mono.wav
# Moved: recording4745.wav_norm_mono.wav
# Moved: recording8160.wav_norm_mono.wav
# Moved: recording9074.wav_norm_mono.wav
# Moved: recording3343.wav_norm_mono.wav
# Moved: recording8803.wav_norm_mono.wav
# Moved: recording9620.wav_norm_mono.wav
# Moved: recording11002.wav_norm_mono.wav
# Moved: recording9423.wav_norm_mono.wav
# Moved: recording11466.wav_norm_mono.wav
# Moved: recording3403.wav_norm_mono.wav
# Moved: recording2426.wav_norm_mono.wav
# Moved: recording9327.wav_norm_mono.wav
# Moved: recording8827.wav_norm_mono.wav
# Moved: recording1491.wav_norm_mono.wav
# Moved: recording5397.wav_norm_mono.wav
# Moved: recording9551.wav_norm_mono.wav
# Moved: recording2366.wav_norm_mono.wav
# Moved: recording8318.wav_norm_mono.wav
# Moved: recording12586.wav_norm_mono.wav
# Moved: recording12517.wav_norm_mono.wav
# Moved: recording4471.wav_norm_mono.wav
# Moved: recording8804.wav_norm_mono.wav
# Moved: recording6452.wav_norm_mono.wav
# Moved: recording1034.wav_norm_mono.wav
# Moved: recording3760.wav_norm_mono.wav
# Moved: recording1195.wav_norm_mono.wav
# Moved: recording9904.wav_norm_mono.wav
# Moved: recording6701.wav_norm_mono.wav
# Moved: recording1038.wav_norm_mono.wav
# Moved: recording10700.wav_norm_mono.wav
# Moved: recording6565.wav_norm_mono.wav
# Moved: recording5153.wav_norm_mono.wav
# Moved: recording8685.wav_norm_mono.wav
# Moved: recording968.wav_norm_mono.wav
# Moved: recording5996.wav_norm_mono.wav
# Moved: recording11459.wav_norm_mono.wav
# Moved: recording2851.wav_norm_mono.wav
# Moved: recording2753.wav_norm_mono.wav
# Moved: recording2718.wav_norm_mono.wav
# Moved: recording2941.wav_norm_mono.wav
# Moved: recording11103.wav_norm_mono.wav
# Moved: recording9638.wav_norm_mono.wav
# Moved: recording4952.wav_norm_mono.wav
# Moved: recording3734.wav_norm_mono.wav
# Moved: recording3233.wav_norm_mono.wav
# Moved: recording9358.wav_norm_mono.wav
# Moved: recording8692.wav_norm_mono.wav
# Moved: recording12664.wav_norm_mono.wav
# Moved: recording4072.wav_norm_mono.wav
# Moved: recording257.wav_norm_mono.wav
# Moved: recording3028.wav_norm_mono.wav
# Moved: recording3253.wav_norm_mono.wav
# Moved: recording3917.wav_norm_mono.wav
# Moved: recording5024.wav_norm_mono.wav
# Moved: recording11412.wav_norm_mono.wav
# Moved: recording4907.wav_norm_mono.wav
# Moved: recording920.wav_norm_mono.wav
# Moved: recording8511.wav_norm_mono.wav
# Moved: recording3603.wav_norm_mono.wav
# Moved: recording4274.wav_norm_mono.wav
# Moved: recording1513.wav_norm_mono.wav
# Moved: recording6477.wav_norm_mono.wav
# Moved: recording9068.wav_norm_mono.wav
# Moved: recording5369.wav_norm_mono.wav
# Moved: recording12093.wav_norm_mono.wav
# Moved: recording7519.wav_norm_mono.wav
# Moved: recording8090.wav_norm_mono.wav
# Moved: recording1537.wav_norm_mono.wav
# Moved: recording6091.wav_norm_mono.wav
# Moved: recording2737.wav_norm_mono.wav
# Moved: recording5284.wav_norm_mono.wav
# Moved: recording8450.wav_norm_mono.wav
# Moved: recording8533.wav_norm_mono.wav
# Moved: recording6347.wav_norm_mono.wav
# Moved: recording9750.wav_norm_mono.wav
# Moved: recording5752.wav_norm_mono.wav
# Moved: recording9990.wav_norm_mono.wav
# Moved: recording1746.wav_norm_mono.wav
# Moved: recording12701.wav_norm_mono.wav
# Moved: recording10244.wav_norm_mono.wav
# Moved: recording6410.wav_norm_mono.wav
# Moved: recording10327.wav_norm_mono.wav
# Moved: recording3632.wav_norm_mono.wav
# Moved: recording7426.wav_norm_mono.wav
# Moved: recording9433.wav_norm_mono.wav
# Moved: recording8247.wav_norm_mono.wav
# Moved: recording11819.wav_norm_mono.wav
# Moved: recording6435.wav_norm_mono.wav
# Moved: recording5892.wav_norm_mono.wav
# Moved: recording8930.wav_norm_mono.wav
# Moved: recording7747.wav_norm_mono.wav
# Moved: recording12045.wav_norm_mono.wav
# Moved: recording12053.wav_norm_mono.wav
# Moved: recording2119.wav_norm_mono.wav
# Moved: recording9228.wav_norm_mono.wav
# Moved: recording6427.wav_norm_mono.wav
# Moved: recording6652.wav_norm_mono.wav
# Moved: recording9407.wav_norm_mono.wav
# Moved: recording1527.wav_norm_mono.wav
# Moved: recording12107.wav_norm_mono.wav
# Moved: recording8652.wav_norm_mono.wav
# Moved: recording2921.wav_norm_mono.wav
# Moved: recording11718.wav_norm_mono.wav
# Moved: recording8254.wav_norm_mono.wav
# Moved: recording7556.wav_norm_mono.wav
# Moved: recording3767.wav_norm_mono.wav
# Moved: recording2219.wav_norm_mono.wav
# Moved: recording5787.wav_norm_mono.wav
# Moved: recording1184.wav_norm_mono.wav
# Moved: recording3751.wav_norm_mono.wav
# Moved: recording10444.wav_norm_mono.wav
# Moved: recording4349.wav_norm_mono.wav
# Moved: recording5464.wav_norm_mono.wav
# Moved: recording9746.wav_norm_mono.wav
# Moved: recording13000.wav_norm_mono.wav
# Moved: recording2232.wav_norm_mono.wav
# Moved: recording10683.wav_norm_mono.wav
# Moved: recording9190.wav_norm_mono.wav
# Moved: recording12481.wav_norm_mono.wav
# Moved: recording6735.wav_norm_mono.wav
# Moved: recording3637.wav_norm_mono.wav
# Moved: recording5359.wav_norm_mono.wav
# Moved: recording3937.wav_norm_mono.wav
# Moved: recording7165.wav_norm_mono.wav
# Moved: recording3070.wav_norm_mono.wav
# Moved: recording8540.wav_norm_mono.wav
# Moved: recording3012.wav_norm_mono.wav
# Moved: recording4705.wav_norm_mono.wav
# Moved: recording11078.wav_norm_mono.wav
# Moved: recording877.wav_norm_mono.wav
# Moved: recording9172.wav_norm_mono.wav
# Moved: recording9023.wav_norm_mono.wav
# Moved: recording5927.wav_norm_mono.wav
# Moved: recording4500.wav_norm_mono.wav
# Moved: recording616.wav_norm_mono.wav
# Moved: recording1675.wav_norm_mono.wav
# Moved: recording9243.wav_norm_mono.wav
# Moved: recording5533.wav_norm_mono.wav
# Moved: recording8154.wav_norm_mono.wav
# Moved: recording8570.wav_norm_mono.wav
# Moved: recording4729.wav_norm_mono.wav
# Moved: recording12248.wav_norm_mono.wav
# Moved: recording1957.wav_norm_mono.wav
# Moved: recording219.wav_norm_mono.wav
# Moved: recording7143.wav_norm_mono.wav
# Moved: recording9917.wav_norm_mono.wav
# Moved: recording4798.wav_norm_mono.wav
# Moved: recording3443.wav_norm_mono.wav
# Moved: recording11949.wav_norm_mono.wav
# Moved: recording11514.wav_norm_mono.wav
# Moved: recording7553.wav_norm_mono.wav
# Moved: recording7269.wav_norm_mono.wav
# Moved: recording7484.wav_norm_mono.wav
# Moved: recording4772.wav_norm_mono.wav
# Moved: recording4635.wav_norm_mono.wav
# Moved: recording4233.wav_norm_mono.wav
# Moved: recording8509.wav_norm_mono.wav
# Moved: recording2018.wav_norm_mono.wav
# Moved: recording193.wav_norm_mono.wav
# Moved: recording6064.wav_norm_mono.wav
# Moved: recording975.wav_norm_mono.wav
# Moved: recording5803.wav_norm_mono.wav
# Moved: recording3678.wav_norm_mono.wav
# Moved: recording5604.wav_norm_mono.wav
# Moved: recording4585.wav_norm_mono.wav
# Moved: recording10763.wav_norm_mono.wav
# Moved: recording6525.wav_norm_mono.wav
# Moved: recording5465.wav_norm_mono.wav
# Moved: recording7294.wav_norm_mono.wav
# Moved: recording2044.wav_norm_mono.wav
# Moved: recording11370.wav_norm_mono.wav
# Moved: recording596.wav_norm_mono.wav
# Moved: recording3524.wav_norm_mono.wav
# Moved: recording6105.wav_norm_mono.wav
# Moved: recording370.wav_norm_mono.wav
# Moved: recording10593.wav_norm_mono.wav
# Moved: recording11609.wav_norm_mono.wav
# Moved: recording6319.wav_norm_mono.wav
# Moved: recording10019.wav_norm_mono.wav
# Moved: recording5172.wav_norm_mono.wav
# Moved: recording12379.wav_norm_mono.wav
# Moved: recording1725.wav_norm_mono.wav
# Moved: recording3882.wav_norm_mono.wav
# Moved: recording12412.wav_norm_mono.wav
# Moved: recording1812.wav_norm_mono.wav
# Moved: recording6939.wav_norm_mono.wav
# Moved: recording5510.wav_norm_mono.wav
# Moved: recording10666.wav_norm_mono.wav
# Moved: recording8095.wav_norm_mono.wav
# Moved: recording1037.wav_norm_mono.wav
# Moved: recording12936.wav_norm_mono.wav
# Moved: recording6897.wav_norm_mono.wav
# Moved: recording11904.wav_norm_mono.wav
# Moved: recording12500.wav_norm_mono.wav
# Moved: recording2013.wav_norm_mono.wav
# Moved: recording8030.wav_norm_mono.wav
# Moved: recording8420.wav_norm_mono.wav
# Moved: recording2881.wav_norm_mono.wav
# Moved: recording3578.wav_norm_mono.wav
# Moved: recording10184.wav_norm_mono.wav
# Moved: recording2549.wav_norm_mono.wav
# Moved: recording7316.wav_norm_mono.wav
# Moved: recording11570.wav_norm_mono.wav
# Moved: recording3060.wav_norm_mono.wav
# Moved: recording9083.wav_norm_mono.wav
# Moved: recording8832.wav_norm_mono.wav
# Moved: recording6540.wav_norm_mono.wav
# Moved: recording5383.wav_norm_mono.wav
# Moved: recording2399.wav_norm_mono.wav
# Moved: recording11731.wav_norm_mono.wav
# Moved: recording5436.wav_norm_mono.wav
# Moved: recording1267.wav_norm_mono.wav
# Moved: recording10998.wav_norm_mono.wav
# Moved: recording2604.wav_norm_mono.wav
# Moved: recording10669.wav_norm_mono.wav
# Moved: recording2311.wav_norm_mono.wav
# Moved: recording10854.wav_norm_mono.wav
# Moved: recording3786.wav_norm_mono.wav
# Moved: recording3062.wav_norm_mono.wav
# Moved: recording11332.wav_norm_mono.wav
# Moved: recording8000.wav_norm_mono.wav
# Moved: recording4806.wav_norm_mono.wav
# Moved: recording4966.wav_norm_mono.wav
# Moved: recording10226.wav_norm_mono.wav
# Moved: recording2809.wav_norm_mono.wav
# Moved: recording10093.wav_norm_mono.wav
# Moved: recording11947.wav_norm_mono.wav
# Moved: recording6099.wav_norm_mono.wav
# Moved: recording6867.wav_norm_mono.wav
# Moved: recording3638.wav_norm_mono.wav
# Moved: recording12394.wav_norm_mono.wav
# Moved: recording5219.wav_norm_mono.wav
# Moved: recording1902.wav_norm_mono.wav
# Moved: recording414.wav_norm_mono.wav
# Moved: recording6492.wav_norm_mono.wav
# Moved: recording8981.wav_norm_mono.wav
# Moved: recording5290.wav_norm_mono.wav
# Moved: recording11436.wav_norm_mono.wav
# Moved: recording5196.wav_norm_mono.wav
# Moved: recording8341.wav_norm_mono.wav
# Moved: recording5214.wav_norm_mono.wav
# Moved: recording9091.wav_norm_mono.wav
# Moved: recording6270.wav_norm_mono.wav
# Moved: recording10528.wav_norm_mono.wav
# Moved: recording7360.wav_norm_mono.wav
# Moved: recording4807.wav_norm_mono.wav
# Moved: recording11057.wav_norm_mono.wav
# Moved: recording6176.wav_norm_mono.wav
# Moved: recording3013.wav_norm_mono.wav
# Moved: recording1300.wav_norm_mono.wav
# Moved: recording452.wav_norm_mono.wav
# Moved: recording11337.wav_norm_mono.wav
# Moved: recording6692.wav_norm_mono.wav
# Moved: recording2508.wav_norm_mono.wav
# Moved: recording8219.wav_norm_mono.wav
# Moved: recording10539.wav_norm_mono.wav
# Moved: recording12263.wav_norm_mono.wav
# Moved: recording3580.wav_norm_mono.wav
# Moved: recording961.wav_norm_mono.wav
# Moved: recording2591.wav_norm_mono.wav
# Moved: recording9122.wav_norm_mono.wav
# Moved: recording470.wav_norm_mono.wav
# Moved: recording3337.wav_norm_mono.wav
# Moved: recording4314.wav_norm_mono.wav
# Moved: recording9571.wav_norm_mono.wav
# Moved: recording6450.wav_norm_mono.wav
# Moved: recording5561.wav_norm_mono.wav
# Moved: recording4542.wav_norm_mono.wav
# Moved: recording11811.wav_norm_mono.wav
# Moved: recording11751.wav_norm_mono.wav
# Moved: recording3265.wav_norm_mono.wav
# Moved: recording11155.wav_norm_mono.wav
# Moved: recording5469.wav_norm_mono.wav
# Moved: recording2820.wav_norm_mono.wav
# Moved: recording4780.wav_norm_mono.wav
# Moved: recording11052.wav_norm_mono.wav
# Moved: recording5543.wav_norm_mono.wav
# Moved: recording9814.wav_norm_mono.wav
# Moved: recording11678.wav_norm_mono.wav
# Moved: recording296.wav_norm_mono.wav
# Moved: recording11185.wav_norm_mono.wav
# Moved: recording1554.wav_norm_mono.wav
# Moved: recording12091.wav_norm_mono.wav
# Moved: recording9507.wav_norm_mono.wav
# Moved: recording304.wav_norm_mono.wav
# Moved: recording7190.wav_norm_mono.wav
# Moved: recording2660.wav_norm_mono.wav
# Moved: recording7204.wav_norm_mono.wav
# Moved: recording12088.wav_norm_mono.wav
# Moved: recording691.wav_norm_mono.wav
# Moved: recording3540.wav_norm_mono.wav
# Moved: recording10690.wav_norm_mono.wav
# Moved: recording7096.wav_norm_mono.wav
# Moved: recording2785.wav_norm_mono.wav
# Moved: recording11348.wav_norm_mono.wav
# Moved: recording9684.wav_norm_mono.wav
# Moved: recording6274.wav_norm_mono.wav
# Moved: recording6912.wav_norm_mono.wav
# Moved: recording2531.wav_norm_mono.wav
# Moved: recording12173.wav_norm_mono.wav
# Moved: recording7562.wav_norm_mono.wav
# Moved: recording11604.wav_norm_mono.wav
# Moved: recording6597.wav_norm_mono.wav
# Moved: recording10597.wav_norm_mono.wav
# Moved: recording7099.wav_norm_mono.wav
# Moved: recording10910.wav_norm_mono.wav
# Moved: recording9254.wav_norm_mono.wav
# Moved: recording12022.wav_norm_mono.wav
# Moved: recording2792.wav_norm_mono.wav
# Moved: recording11060.wav_norm_mono.wav
# Moved: recording11054.wav_norm_mono.wav
# Moved: recording1407.wav_norm_mono.wav
# Moved: recording7650.wav_norm_mono.wav
# Moved: recording1789.wav_norm_mono.wav
# Moved: recording9770.wav_norm_mono.wav
# Moved: recording12669.wav_norm_mono.wav
# Moved: recording11375.wav_norm_mono.wav
# Moved: recording5594.wav_norm_mono.wav
# Moved: recording4122.wav_norm_mono.wav
# Moved: recording689.wav_norm_mono.wav
# Moved: recording7486.wav_norm_mono.wav
# Moved: recording3311.wav_norm_mono.wav
# Moved: recording5411.wav_norm_mono.wav
# Moved: recording823.wav_norm_mono.wav
# Moved: recording11232.wav_norm_mono.wav
# Moved: recording899.wav_norm_mono.wav
# Moved: recording421.wav_norm_mono.wav
# Moved: recording6236.wav_norm_mono.wav
# Moved: recording4226.wav_norm_mono.wav
# Moved: recording6174.wav_norm_mono.wav
# Moved: recording5333.wav_norm_mono.wav
# Moved: recording343.wav_norm_mono.wav
# Moved: recording6445.wav_norm_mono.wav
# Moved: recording1517.wav_norm_mono.wav
# Moved: recording11014.wav_norm_mono.wav
# Moved: recording1642.wav_norm_mono.wav
# Moved: recording3683.wav_norm_mono.wav
# Moved: recording4103.wav_norm_mono.wav
# Moved: recording2616.wav_norm_mono.wav
# Moved: recording5652.wav_norm_mono.wav
# Moved: recording10783.wav_norm_mono.wav
# Moved: recording11239.wav_norm_mono.wav
# Moved: recording9879.wav_norm_mono.wav
# Moved: recording6547.wav_norm_mono.wav
# Moved: recording12680.wav_norm_mono.wav
# Moved: recording4864.wav_norm_mono.wav
# Moved: recording4508.wav_norm_mono.wav
# Moved: recording10540.wav_norm_mono.wav
# Moved: recording4840.wav_norm_mono.wav
# Moved: recording3002.wav_norm_mono.wav
# Moved: recording890.wav_norm_mono.wav
# Moved: recording11945.wav_norm_mono.wav
# Moved: recording1820.wav_norm_mono.wav
# Moved: recording10824.wav_norm_mono.wav
# Moved: recording6458.wav_norm_mono.wav
# Moved: recording9135.wav_norm_mono.wav
# Moved: recording8844.wav_norm_mono.wav
# Moved: recording9676.wav_norm_mono.wav
# Moved: recording4005.wav_norm_mono.wav
# Moved: recording9801.wav_norm_mono.wav
# Moved: recording7202.wav_norm_mono.wav
# Moved: recording11525.wav_norm_mono.wav
# Moved: recording2956.wav_norm_mono.wav
# Moved: recording12488.wav_norm_mono.wav
# Moved: recording10138.wav_norm_mono.wav
# Moved: recording6267.wav_norm_mono.wav
# Moved: recording9341.wav_norm_mono.wav
# Moved: recording9200.wav_norm_mono.wav
# Moved: recording7630.wav_norm_mono.wav
# Moved: recording7224.wav_norm_mono.wav
# Moved: recording4818.wav_norm_mono.wav
# Moved: recording7878.wav_norm_mono.wav
# Moved: recording715.wav_norm_mono.wav
# Moved: recording6441.wav_norm_mono.wav
# Moved: recording3456.wav_norm_mono.wav
# Moved: recording10589.wav_norm_mono.wav
# Moved: recording11828.wav_norm_mono.wav
# Moved: recording3441.wav_norm_mono.wav
# Moved: recording4972.wav_norm_mono.wav
# Moved: recording10821.wav_norm_mono.wav
# Moved: recording4356.wav_norm_mono.wav
# Moved: recording6207.wav_norm_mono.wav
# Moved: recording2229.wav_norm_mono.wav
# Moved: recording5647.wav_norm_mono.wav
# Moved: recording6646.wav_norm_mono.wav
# Moved: recording8805.wav_norm_mono.wav
# Moved: recording5453.wav_norm_mono.wav
# Moved: recording5685.wav_norm_mono.wav
# Moved: recording1232.wav_norm_mono.wav
# Moved: recording1762.wav_norm_mono.wav
# Moved: recording1962.wav_norm_mono.wav
# Moved: recording752.wav_norm_mono.wav
# Moved: recording1.wav_norm_mono.wav
# Moved: recording5914.wav_norm_mono.wav
# Moved: recording3219.wav_norm_mono.wav
# Moved: recording6085.wav_norm_mono.wav
# Moved: recording5620.wav_norm_mono.wav
# Moved: recording1937.wav_norm_mono.wav
# Moved: recording8877.wav_norm_mono.wav
#
# Total files moved: 10208 from 'data/FOR/FOR_dataset/training' → 'data/FOR/FOR_dataset'

# %%
import shutil
import os

def delete_folder(folder_path):
    """
    Deletes the specified folder and all its contents.

    Parameters:
    - folder_path (str): The full path to the folder to delete.
    """
    if os.path.exists(folder_path) and os.path.isdir(folder_path):
        try:
            shutil.rmtree(folder_path)
            print(f"Deleted folder: {folder_path}")
        except Exception as e:
            print(f"Error deleting folder: {e}")
    else:
        print(f"Folder does not exist or is not a directory: {folder_path}")

folder_to_delete = 'data/FOR/validation/fake'
delete_folder(folder_to_delete)
folder_to_delete = 'data/FOR/validation/real'
delete_folder(folder_to_delete)
# Out:
# Folder does not exist or is not a directory: data/FOR/validation/fake
# Folder does not exist or is not a directory: data/FOR/validation/real

# %%
import pandas as pd

# Load your CSV file
csv_path = './data/FOR/FOR_metadata.csv'
df = pd.read_csv(csv_path)

# Show existing columns
print("Before renaming:", df.columns.tolist())

# Rename a column
# Example: Rename 'filename' → 'file_name'
df.rename(columns={'filename': 'file'}, inplace=True)

# Confirm the change
print("After renaming:", df.columns.tolist())

# Save the updated CSV (overwrite or save as new)
df.to_csv(csv_path, index=False)
# Or: df.to_csv('./data/ASVspoofBalanced/renamed_metadata.csv', index=False)
# Out:
# Before renaming: ['filename', 'path', 'label', 'split']
# After renaming: ['file', 'path', 'label', 'split']
